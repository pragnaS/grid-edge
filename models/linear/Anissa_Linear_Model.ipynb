# %%
import numpy as np
from numpy import linalg as LA
import pandas as pd
import os

# %% [markdown]
# # Data Preprocessing

# %%
#reading 3 phase DPMU output from gridlabD
dpmu_phaseA = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\aug\multi_voltageA.csv')
dpmu_phaseB = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\aug\multi_voltageB.csv')
dpmu_phaseC = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\aug\multi_voltageC.csv')

# %%
dpmu_phaseA
# Out:
#                    # timestamp                  Meter2  \
# 0      2018-08-01 00:00:00 CDT    +2401.78-6.677e-010i
# 1      2018-08-01 00:01:00 CDT  +2401.78-1.53652e-009i
# 2      2018-08-01 00:02:00 CDT  +2401.78+4.96263e-009i
# 3      2018-08-01 00:03:00 CDT  +2401.78-2.99842e-010i
# 4      2018-08-01 00:04:00 CDT  +2401.78+4.62254e-009i
# ...                        ...                     ...
# 44635  2018-08-31 23:55:00 CDT       +2389.12-25.6399i
# 44636  2018-08-31 23:56:00 CDT       +2379.96-24.6927i
# 44637  2018-08-31 23:57:00 CDT       +2380.08-18.0444i
# 44638  2018-08-31 23:58:00 CDT       +2378.04-19.9124i
# 44639  2018-08-31 23:59:00 CDT       +2374.58-19.8343i
#
#                        Meter1       Meter5                  Meter3  \
# 0      +2401.78-6.67515e-010i  +2401.78+0i   +2401.78-1.3315e-009i
# 1      +2401.78-1.53672e-009i  +2401.78+0i   +2401.78-3.0723e-009i
# 2      +2401.78+4.96245e-009i  +2401.78+0i  +2401.78+9.92528e-009i
# 3      +2401.78-3.00259e-010i  +2401.78+0i   +2401.78-6.0017e-010i
# 4       +2401.78+4.6224e-009i  +2401.78+0i  +2401.78+9.24438e-009i
# ...                       ...          ...                     ...
# 44635        +2388.2-25.7631i  +2401.78+0i       +2373.81-48.3224i
# 44636       +2379.21-25.2192i  +2401.78+0i       +2363.39-42.3781i
# 44637       +2379.32-19.0202i  +2401.78+0i       +2361.72-33.4432i
# 44638       +2378.64-19.5764i  +2401.78+0i        +2363.58-35.246i
# 44639       +2375.59-19.0548i  +2401.78+0i       +2357.51-32.7207i
#
#                        Meter4                   1_2_3                   4_5_6  \
# 0      +2401.78-1.33273e-009i    +2401.78-6.677e-010i  +2401.78-6.68147e-010i
# 1      +2401.78-3.07346e-009i  +2401.78-1.53652e-009i  +2401.78-1.53709e-009i
# 2      +2401.78+9.92464e-009i  +2401.78+4.96263e-009i  +2401.78+4.96189e-009i
# 3      +2401.78-6.00645e-010i  +2401.78-2.99842e-010i  +2401.78-3.00993e-010i
# 4       +2401.78+9.2435e-009i  +2401.78+4.62254e-009i  +2401.78+4.62166e-009i
# ...                       ...                     ...                     ...
# 44635       +2371.55-50.2265i       +2386.95-27.1563i       +2385.93-26.5561i
# 44636       +2361.31-43.3462i       +2377.89-26.2714i       +2372.97-27.3556i
# 44637       +2359.84-33.9173i        +2378.17-19.716i          +2374-21.1249i
# 44638       +2361.73-35.8699i        +2368.4-28.2786i       +2374.27-19.8813i
# 44639       +2355.45-33.1625i       +2361.97-29.1408i       +2371.69-19.3368i
#
#                         7_8_9                13_14_15                10_11_12  \
# 0      +2401.78-6.68147e-010i  +2401.78-1.33273e-009i   +2401.78-1.3315e-009i
# 1      +2401.78-1.53709e-009i  +2401.78-3.07346e-009i   +2401.78-3.0723e-009i
# 2      +2401.78+4.96189e-009i  +2401.78+9.92464e-009i  +2401.78+9.92528e-009i
# 3      +2401.78-3.00993e-010i  +2401.78-6.00645e-010i   +2401.78-6.0017e-010i
# 4      +2401.78+4.62166e-009i   +2401.78+9.2435e-009i  +2401.78+9.24438e-009i
# ...                       ...                     ...                     ...
# 44635       +2384.19-27.3061i       +2367.26-49.5283i       +2373.81-48.3224i
# 44636       +2371.17-28.0541i       +2357.01-42.3523i       +2363.39-42.3781i
# 44637        +2372.6-21.6941i       +2355.56-32.8314i       +2361.72-33.4432i
# 44638       +2373.68-19.5555i       +2357.41-34.9363i        +2363.58-35.246i
# 44639       +2371.37-18.9448i       +2351.27-32.2654i       +2357.51-32.7207i
#
#                      22_23_24                19_20_21                16_17_18
# 0       +2401.78-1.3316e-009i   +2401.78-1.3316e-009i  +2401.78-1.33273e-009i
# 1      +2401.78-3.07208e-009i  +2401.78-3.07208e-009i  +2401.78-3.07346e-009i
# 2      +2401.78+9.92528e-009i  +2401.78+9.92528e-009i  +2401.78+9.92464e-009i
# 3      +2401.78-5.99992e-010i  +2401.78-5.99992e-010i  +2401.78-6.00645e-010i
# 4      +2401.78+9.24428e-009i  +2401.78+9.24428e-009i   +2401.78+9.2435e-009i
# ...                       ...                     ...                     ...
# 44635       +2372.97-49.0974i       +2373.81-48.3195i        +2370.78-50.711i
# 44636        +2362.5-43.1028i        +2363.39-42.375i       +2361.07-43.5705i
# 44637       +2360.82-34.0922i         +2361.71-33.44i       +2359.92-34.0828i
# 44638       +2362.71-35.8845i        +2363.58-35.243i       +2361.79-36.0449i
# 44639       +2356.68-33.4015i       +2357.51-32.7176i       +2355.52-33.3832i
#
# [44640 rows x 14 columns]

# %%
# dropping meter data
# dpmu_phaseA = dpmu_phaseA.drop(['Meter1', 'Meter2', 'Meter3', 'Meter4', 'Meter5', '# timestamp'], axis=1)
# dpmu_phaseB = dpmu_phaseB.drop(['Meter1', 'Meter2', 'Meter3', 'Meter4', 'Meter5', '# timestamp'], axis=1)
# dpmu_phaseC = dpmu_phaseC.drop(['Meter1', 'Meter2', 'Meter3', 'Meter4', 'Meter5', '# timestamp'], axis=1)

dpmu_phaseA = dpmu_phaseA.drop(['Meter5', '# timestamp'], axis=1)
dpmu_phaseB = dpmu_phaseB.drop(['Meter5', '# timestamp'], axis=1)
dpmu_phaseC = dpmu_phaseC.drop(['Meter5', '# timestamp'], axis=1)

# %%
phaseA = 0
phaseB = 1
phaseC = 2

# %%
# creating target dpmu dataframe
dpmu_data = pd.DataFrame()

# %%
for (columnName, columnData) in dpmu_phaseA.iteritems():
    i=0
    if 'Meter' in columnName:
        split = columnName.split('Meter')
        house_name = 'MeterA_'+ split[1]
        i+=1
        dpmu_values = pd.Series(columnData.values).str.replace("i", "j").apply(lambda x: abs(complex(x)))
        dpmu_data[house_name] = dpmu_values
    else:
        split_column_names = columnName.split('_')
        house_name = 'house'+str(split_column_names[phaseA])
        dpmu_values = pd.Series(columnData.values).str.replace("i", "j").apply(lambda x: abs(complex(x)))
        dpmu_data[house_name] = dpmu_values

# %%
for (columnName, columnData) in dpmu_phaseB.iteritems():
    i=0
    if 'Meter' in columnName:
        split = columnName.split('Meter')
        house_name = 'MeterB_'+ split[1]
        i+=1
        dpmu_values = pd.Series(columnData.values).str.replace("i", "j").apply(lambda x: abs(complex(x)))
        dpmu_data[house_name] = dpmu_values
    else:
        split_column_names = columnName.split('_')
        house_name = 'house'+str(split_column_names[phaseB])
        dpmu_values = pd.Series(columnData.values).str.replace("i", "j").apply(lambda x: abs(complex(x)))
        dpmu_data[house_name] = dpmu_values

# %%
for (columnName, columnData) in dpmu_phaseC.iteritems():
    i=0
    if 'Meter' in columnName:
        split = columnName.split('Meter')
        house_name = 'MeterC_'+ split[1]
        i+=1
        dpmu_values = pd.Series(columnData.values).str.replace("i", "j").apply(lambda x: abs(complex(x)))
        dpmu_data[house_name] = dpmu_values
    else:
        split_column_names = columnName.split('_')
        house_name = 'house'+str(split_column_names[phaseC])
        dpmu_values = pd.Series(columnData.values).str.replace("i", "j").apply(lambda x: abs(complex(x)))
        dpmu_data[house_name] = dpmu_values

# %%
dpmu_data
# Out:
#           MeterA_2     MeterA_1     MeterA_3     MeterA_4       house1  \
# 0      2401.780000  2401.780000  2401.780000  2401.780000  2401.780000
# 1      2401.780000  2401.780000  2401.780000  2401.780000  2401.780000
# 2      2401.780000  2401.780000  2401.780000  2401.780000  2401.780000
# 3      2401.780000  2401.780000  2401.780000  2401.780000  2401.780000
# 4      2401.780000  2401.780000  2401.780000  2401.780000  2401.780000
# ...            ...          ...          ...          ...          ...
# 44635  2389.257579  2388.338958  2374.301786  2372.081808  2387.104473
# 44636  2380.088093  2379.343656  2363.769912  2361.707816  2378.035121
# 44637  2380.148400  2379.396022  2361.956775  2360.083729  2378.251725
# 44638  2378.123366  2378.720556  2363.842782  2362.002380  2368.568817
# 44639  2374.662834  2375.666419  2357.737060  2355.683437  2362.149755
#
#             house4       house7      house13      house10      house22  ...  \
# 0      2401.780000  2401.780000  2401.780000  2401.780000  2401.780000  ...
# 1      2401.780000  2401.780000  2401.780000  2401.780000  2401.780000  ...
# 2      2401.780000  2401.780000  2401.780000  2401.780000  2401.780000  ...
# 3      2401.780000  2401.780000  2401.780000  2401.780000  2401.780000  ...
# 4      2401.780000  2401.780000  2401.780000  2401.780000  2401.780000  ...
# ...            ...          ...          ...          ...          ...  ...
# 44635  2386.077784  2384.346363  2367.778064  2374.301786  2373.477865  ...
# 44636  2373.127672  2371.335953  2357.390476  2363.769912  2362.893163  ...
# 44637  2374.093987  2372.699179  2355.788788  2361.956775  2361.066147  ...
# 44638  2374.353238  2373.760552  2357.668860  2363.842782  2362.982489  ...
# 44639  2371.768827  2371.445673  2351.491371  2357.737060  2356.916690  ...
#
#           MeterC_3     MeterC_4       house3       house6       house9  \
# 0      2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 1      2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 2      2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 3      2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 4      2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# ...            ...          ...          ...          ...          ...
# 44635  2339.909057  2334.546595  2343.973200  2359.890256  2359.394598
# 44636  2346.367529  2341.574198  2346.678386  2362.453781  2361.973655
# 44637  2355.168952  2350.812653  2354.201535  2368.498071  2368.096015
# 44638  2352.947005  2348.389288  2351.468713  2368.473856  2368.612726
# 44639  2361.530329  2358.183755  2353.803893  2372.652522  2372.809565
#
#            house15      house12      house24      house21      house18
# 0      2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 1      2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 2      2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 3      2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 4      2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# ...            ...          ...          ...          ...          ...
# 44635  2328.649481  2339.909057  2336.996585  2339.909057  2332.862052
# 44636  2335.601307  2346.367529  2343.556913  2346.367529  2339.980284
# 44637  2344.869655  2355.168952  2352.457341  2355.168952  2349.198187
# 44638  2342.397342  2352.947005  2350.347309  2352.947005  2346.753160
# 44639  2354.149282  2361.530329  2358.928047  2361.535132  2356.402632
#
# [44640 rows x 36 columns]

# %%
# creating input grid dataframe
input_player_df = pd.DataFrame()

# %%
directory = r"C:\Users\aniss\grid-edge\data\summer\input_csv\aug"

for filename in os.listdir(directory):
    if str(filename).startswith('25.csv'):
        continue
    player = pd.read_csv(os.path.join(directory, filename))
    player['grid'] = player['grid'].str.replace("i", "j").apply(lambda x: complex(x))
    node_id = player['id'].loc[0]
    column_name_p = 'p_'+str(node_id)
    column_name_q = 'q_'+str(node_id)
#change .head() value to target dataframe row number
    input_player_df[column_name_p] = player['grid'].apply(lambda x: x.real).head(44640)
    input_player_df[column_name_q] = player['grid'].apply(lambda x: x.imag).head(44640)

# %%
input_player_df
# Out:
#            p_1           q_1     p_10          q_10     p_11          q_11  \
# 0      43770.0  16469.310048  49815.0  22403.753687   6210.0   2695.012019
# 1      43800.0  16489.442538  49830.0  18118.185743   6210.0   2652.451633
# 2      43740.0  18093.970905  49980.0  16776.366378   6210.0   2155.374490
# 3      43695.0  20767.052779  49920.0  19616.208244   6210.0   2420.677435
# 4      43635.0  16530.779025  49875.0  22098.446062   6210.0   2789.715225
# ...        ...           ...      ...           ...      ...           ...
# 44635   6720.0   2783.210231  52035.0  24418.630981  72225.0  28203.239226
# 44636   5550.0   2539.380180  51960.0  24852.282395  72255.0  26619.217900
# 44637   5535.0   2377.145083  51870.0  23536.594064  72210.0  28591.535057
# 44638   5535.0   2511.753480  51870.0  23979.794916  40785.0  17449.052683
# 44639   5550.0   2401.784284  51825.0  19060.016572  25500.0  11404.569433
#
#          p_12         q_12      p_13          q_13  ...      p_5  \
# 0      7680.0  3179.099513   61020.0  29502.531393  ...  53790.0
# 1      7410.0  3283.708947   60975.0  25982.549038  ...  53640.0
# 2      7410.0  2942.624906   95295.0  39878.190122  ...  53670.0
# 3      7410.0  2509.893336  111255.0  50618.963361  ...  53565.0
# 4      8385.0  3529.459545  105225.0  38872.747755  ...  53520.0
# ...       ...          ...       ...           ...  ...      ...
# 44635  7695.0  3620.339227    6930.0   2692.723848  ...  54600.0
# 44636  7920.0  2863.564594    6195.0   2286.259900  ...  54690.0
# 44637  7890.0  2850.166224    6210.0   2648.898031  ...  54660.0
# 44638  7830.0  3075.092810    6225.0   2808.420788  ...  54765.0
# 44639  7935.0  3088.602381    6180.0   2872.144530  ...  54555.0
#
#                 q_5      p_6           q_6      p_7           q_7     p_8  \
# 0      25326.903353  67515.0  31808.368293  29070.0  10529.067416  6045.0
# 1      18459.901687  67395.0  27014.072442  39240.0  14900.141805  6090.0
# 2      21365.140495  67035.0  31328.887859  39525.0  16323.012981  6165.0
# 3      23865.960887  67005.0  32052.445552  39675.0  13387.876143  8325.0
# 4      18590.917043  67050.0  29373.794538  39645.0  15676.843795  7950.0
# ...             ...      ...           ...      ...           ...     ...
# 44635  19755.024567  70620.0  33218.534846  40200.0  19088.771038  5775.0
# 44636  20617.117340  70425.0  29445.121614  40395.0  16284.382985  4815.0
# 44637  21157.921748  70515.0  33171.664766  40545.0  17106.067338  4800.0
# 44638  21260.283351  70425.0  24380.417452  14040.0   5889.002648  4800.0
# 44639  23807.403348  70545.0  23658.398890   8730.0   3479.767501  4800.0
#
#                q_8     p_9          q_9
# 0      2515.278484  5310.0  2237.349195
# 1      2647.371431  5295.0  2050.646953
# 2      2984.864340  5265.0  2429.566369
# 3      4010.588460  5280.0  1755.293115
# 4      3506.616212  5265.0  1780.150155
# ...            ...     ...          ...
# 44635  2554.586466  7305.0  3011.122825
# 44636  1931.008371  7185.0  3239.030520
# 44637  1607.936207  7140.0  3206.669993
# 44638  1907.035168  7155.0  2937.867317
# 44639  2054.864040  7155.0  2892.343938
#
# [44640 rows x 48 columns]

# %% [markdown]
# # Concat all Summer Data

# %%
def DPMU(phase,dpmu_data,phase_letter,letter):
    for (columnName, columnData) in phase.iteritems():
        i=0
        if 'Meter' in columnName:
            split = columnName.split('Meter')
            house_name = f'Meter{letter}_'+ split[1]
            i+=1
            dpmu_values = pd.Series(columnData.values).str.replace("i", "j").apply(lambda x: abs(complex(x)))
            dpmu_data[house_name] = dpmu_values
        else:
            split_column_names = columnName.split('_')
            house_name = 'house'+str(split_column_names[phase_letter])
            dpmu_values = pd.Series(columnData.values).str.replace("i", "j").apply(lambda x: abs(complex(x)))
            dpmu_data[house_name] = dpmu_values
    return dpmu_data

# %%
def Input(month,input_player_df):
    directory = fr'C:\Users\aniss\grid-edge\data\summer\input_csv\{month}'

    for filename in os.listdir(directory):
        if str(filename).startswith('25.csv'):
            continue
        player = pd.read_csv(os.path.join(directory, filename))
        player['grid'] = player['grid'].str.replace("i", "j").apply(lambda x: complex(x))
        node_id = player['id'].loc[0]
        column_name_p = 'p_'+str(node_id)
        column_name_q = 'q_'+str(node_id)
    #change .head() value to target dataframe row number
        input_player_df[column_name_p] = player['grid'].apply(lambda x: x.real).head(44640)
        input_player_df[column_name_q] = player['grid'].apply(lambda x: x.imag).head(44640)
    return input_player_df

# %%
dpmu_phaseA_aug = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\trimmed_targets\aug\multi_voltageA.csv')
dpmu_phaseB_aug = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\trimmed_targets\aug\multi_voltageB.csv')
dpmu_phaseC_aug = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\trimmed_targets\aug\multi_voltageC.csv')

dpmu_phaseA_july = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\trimmed_targets\july\multi_voltageA.csv')
dpmu_phaseB_july = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\trimmed_targets\july\multi_voltageB.csv')
dpmu_phaseC_july = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\trimmed_targets\july\multi_voltageC.csv')

dpmu_phaseA_june = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\trimmed_targets\june\multi_voltageA.csv')
dpmu_phaseB_june = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\trimmed_targets\june\multi_voltageB.csv')
dpmu_phaseC_june = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\trimmed_targets\june\multi_voltageC.csv')

dpmu_phaseA_sept = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\trimmed_targets\sept\multi_voltageA.csv')
dpmu_phaseB_sept = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\trimmed_targets\sept\multi_voltageB.csv')
dpmu_phaseC_sept = pd.read_csv(r'C:\Users\aniss\grid-edge\data\summer\targets\trimmed_targets\sept\multi_voltageC.csv')

# %%
dpmu_phaseA_aug = dpmu_phaseA_aug.drop(['Meter5', '# timestamp'], axis=1)
dpmu_phaseB_aug = dpmu_phaseB_aug.drop(['Meter5', '# timestamp'], axis=1)
dpmu_phaseC_aug = dpmu_phaseC_aug.drop(['Meter5', '# timestamp'], axis=1)

dpmu_phaseA_july = dpmu_phaseA_july.drop(['Meter5', '# timestamp'], axis=1)
dpmu_phaseB_july = dpmu_phaseB_july.drop(['Meter5', '# timestamp'], axis=1)
dpmu_phaseC_july = dpmu_phaseC_july.drop(['Meter5', '# timestamp'], axis=1)

dpmu_phaseA_june = dpmu_phaseA_june.drop(['Meter5', '# timestamp'], axis=1)
dpmu_phaseB_june = dpmu_phaseB_june.drop(['Meter5', '# timestamp'], axis=1)
dpmu_phaseC_june = dpmu_phaseC_june.drop(['Meter5', '# timestamp'], axis=1)

dpmu_phaseA_sept = dpmu_phaseA_sept.drop(['Meter5', '# timestamp'], axis=1)
dpmu_phaseB_sept = dpmu_phaseB_sept.drop(['Meter5', '# timestamp'], axis=1)
dpmu_phaseC_sept = dpmu_phaseC_sept.drop(['Meter5', '# timestamp'], axis=1)

# %%
phaseA = 0
phaseB = 1
phaseC = 2
A = "A"
B = "B"
C = "C"

# %%
dpmu_data_aug = pd.DataFrame()
dpmu_data_july = pd.DataFrame()
dpmu_data_june = pd.DataFrame()
dpmu_data_sept = pd.DataFrame()

# %%
dpmu_data_aug = DPMU(dpmu_phaseA_aug,dpmu_data_aug,phaseA, A)
dpmu_data_aug = DPMU(dpmu_phaseB_aug,dpmu_data_aug, phaseB, B)
dpmu_data_aug = DPMU(dpmu_phaseC_aug,dpmu_data_aug, phaseC, C)

dpmu_data_july = DPMU(dpmu_phaseA_aug,dpmu_data_july,phaseA, A)
dpmu_data_july = DPMU(dpmu_phaseB_aug,dpmu_data_july, phaseB, B)
dpmu_data_july = DPMU(dpmu_phaseC_aug,dpmu_data_july, phaseC, C)

dpmu_data_june = DPMU(dpmu_phaseA_aug,dpmu_data_june,phaseA, A)
dpmu_data_june = DPMU(dpmu_phaseB_aug,dpmu_data_june, phaseB, B)
dpmu_data_june = DPMU(dpmu_phaseC_aug,dpmu_data_june, phaseC, C)

dpmu_data_sept = DPMU(dpmu_phaseA_aug,dpmu_data_sept,phaseA, A)
dpmu_data_sept = DPMU(dpmu_phaseB_aug,dpmu_data_sept, phaseB, B)
dpmu_data_sept = DPMU(dpmu_phaseC_aug,dpmu_data_sept, phaseC, C)

# %%
dpmu_data = pd.DataFrame()
dpmu_data = pd.concat([dpmu_data_aug, dpmu_data_july,dpmu_data_june,dpmu_data_sept], ignore_index = True)

# %%
dpmu_data
# Out:
#            MeterA_2     MeterA_1     MeterA_3     MeterA_4       house1  \
# 0       2401.780000  2401.780000  2401.780000  2401.780000  2401.780000
# 1       2401.780000  2401.780000  2401.780000  2401.780000  2401.780000
# 2       2401.780000  2401.780000  2401.780000  2401.780000  2401.780000
# 3       2401.780000  2401.780000  2401.780000  2401.780000  2401.780000
# 4       2401.780000  2401.780000  2401.780000  2401.780000  2401.780000
# ...             ...          ...          ...          ...          ...
# 178555  2389.257579  2388.338958  2374.301786  2372.081808  2387.104473
# 178556  2380.088093  2379.343656  2363.769912  2361.707816  2378.035121
# 178557  2380.148400  2379.396022  2361.956775  2360.083729  2378.251725
# 178558  2378.123366  2378.720556  2363.842782  2362.002380  2368.568817
# 178559  2374.662834  2375.666419  2357.737060  2355.683437  2362.149755
#
#              house4       house7      house13      house10      house22  ...  \
# 0       2401.780000  2401.780000  2401.780000  2401.780000  2401.780000  ...
# 1       2401.780000  2401.780000  2401.780000  2401.780000  2401.780000  ...
# 2       2401.780000  2401.780000  2401.780000  2401.780000  2401.780000  ...
# 3       2401.780000  2401.780000  2401.780000  2401.780000  2401.780000  ...
# 4       2401.780000  2401.780000  2401.780000  2401.780000  2401.780000  ...
# ...             ...          ...          ...          ...          ...  ...
# 178555  2386.077784  2384.346363  2367.778064  2374.301786  2373.477865  ...
# 178556  2373.127672  2371.335953  2357.390476  2363.769912  2362.893163  ...
# 178557  2374.093987  2372.699179  2355.788788  2361.956775  2361.066147  ...
# 178558  2374.353238  2373.760552  2357.668860  2363.842782  2362.982489  ...
# 178559  2371.768827  2371.445673  2351.491371  2357.737060  2356.916690  ...
#
#            MeterC_3     MeterC_4       house3       house6       house9  \
# 0       2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 1       2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 2       2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 3       2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 4       2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# ...             ...          ...          ...          ...          ...
# 178555  2339.909057  2334.546595  2343.973200  2359.890256  2359.394598
# 178556  2346.367529  2341.574198  2346.678386  2362.453781  2361.973655
# 178557  2355.168952  2350.812653  2354.201535  2368.498071  2368.096015
# 178558  2352.947005  2348.389288  2351.468713  2368.473856  2368.612726
# 178559  2361.530329  2358.183755  2353.803893  2372.652522  2372.809565
#
#             house15      house12      house24      house21      house18
# 0       2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 1       2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 2       2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 3       2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# 4       2401.777840  2401.777840  2401.777840  2401.777840  2401.777840
# ...             ...          ...          ...          ...          ...
# 178555  2328.649481  2339.909057  2336.996585  2339.909057  2332.862052
# 178556  2335.601307  2346.367529  2343.556913  2346.367529  2339.980284
# 178557  2344.869655  2355.168952  2352.457341  2355.168952  2349.198187
# 178558  2342.397342  2352.947005  2350.347309  2352.947005  2346.753160
# 178559  2354.149282  2361.530329  2358.928047  2361.535132  2356.402632
#
# [178560 rows x 36 columns]

# %%
dpmu_data_2 = dpmu_data[0:175680]

# %%
aug = "aug"
july = "july"
june = "june"
sept = "sept"

# %%
input_player_df_aug = pd.DataFrame()
input_player_df_july = pd.DataFrame()
input_player_df_june = pd.DataFrame()
input_player_df_sept = pd.DataFrame()

# %%
input_player_df_aug = Input(aug,input_player_df_aug)
input_player_df_july = Input(july,input_player_df_july)
input_player_df_june = Input(june,input_player_df_june)
input_player_df_sept = Input(sept,input_player_df_sept)

# %%
input_player_df = pd.DataFrame()
input_player_df = pd.concat([input_player_df_aug,input_player_df_july,input_player_df_june,input_player_df_sept], ignore_index=True)

# %%
input_player_df
# Out:
#             p_1           q_1     p_10          q_10     p_11          q_11  \
# 0       43770.0  16469.310048  49815.0  22403.753687   6210.0   2695.012019
# 1       43800.0  16489.442538  49830.0  18118.185743   6210.0   2652.451633
# 2       43740.0  18093.970905  49980.0  16776.366378   6210.0   2155.374490
# 3       43695.0  20767.052779  49920.0  19616.208244   6210.0   2420.677435
# 4       43635.0  16530.779025  49875.0  22098.446062   6210.0   2789.715225
# ...         ...           ...      ...           ...      ...           ...
# 175675   6465.0   2972.631054  45765.0  18601.907100  50505.0  22584.311886
# 175676   7725.0   2803.379395  45735.0  18923.346659  24030.0  11340.509535
# 175677   7650.0   3236.531135  45810.0  21489.054438  18000.0   7522.310477
# 175678   7635.0   3083.770012  46065.0  21513.366251   8415.0   3805.158132
# 175679   7605.0   3020.594584  46575.0  19290.612690   8445.0   3474.045117
#
#            p_12          q_12      p_13          q_13  ...      p_5  \
# 0        7680.0   3179.099513   61020.0  29502.531393  ...  53790.0
# 1        7410.0   3283.708947   60975.0  25982.549038  ...  53640.0
# 2        7410.0   2942.624906   95295.0  39878.190122  ...  53670.0
# 3        7410.0   2509.893336  111255.0  50618.963361  ...  53565.0
# 4        8385.0   3529.459545  105225.0  38872.747755  ...  53520.0
# ...         ...           ...       ...           ...  ...      ...
# 175675   8430.0   3328.588776   57450.0  19299.682650  ...   4650.0
# 175676  23640.0   8755.127495   57855.0  26046.266930  ...   4635.0
# 175677  38730.0  18340.170000   59265.0  22983.504280  ...   4635.0
# 175678  39315.0  17865.066637   58860.0  26649.707408  ...   4620.0
# 175679  39855.0  13545.269484   57000.0  22595.054086  ...   4620.0
#
#                  q_5      p_6           q_6      p_7           q_7      p_8  \
# 0       25326.903353  67515.0  31808.368293  29070.0  10529.067416   6045.0
# 1       18459.901687  67395.0  27014.072442  39240.0  14900.141805   6090.0
# 2       21365.140495  67035.0  31328.887859  39525.0  16323.012981   6165.0
# 3       23865.960887  67005.0  32052.445552  39675.0  13387.876143   8325.0
# 4       18590.917043  67050.0  29373.794538  39645.0  15676.843795   7950.0
# ...              ...      ...           ...      ...           ...      ...
# 175675   2208.508764  64635.0  27202.534073   4740.0   1914.997235  41190.0
# 175676   1960.976683  62775.0  30129.325651   4725.0   2195.820777  39915.0
# 175677   1702.780467  62595.0  26224.452040   3105.0   1118.742920  39375.0
# 175678   1994.933092  61470.0  26974.300793   2745.0   1055.999958  39315.0
# 175679   2002.153931  60735.0  22461.170215   2745.0   1022.199878  22200.0
#
#                  q_8     p_9          q_9
# 0        2515.278484  5310.0  2237.349195
# 1        2647.371431  5295.0  2050.646953
# 2        2984.864340  5265.0  2429.566369
# 3        4010.588460  5280.0  1755.293115
# 4        3506.616212  5265.0  1780.150155
# ...              ...     ...          ...
# 175675  14957.027472  6705.0  2756.050831
# 175676  16715.076021  6645.0  2334.949333
# 175677  18243.365479  6645.0  2331.013497
# 175678  14768.401004  6645.0  3114.604813
# 175679   8835.499844  6630.0  2507.588774
#
# [175680 rows x 48 columns]

# %% [markdown]
# # Linear Model Training

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression, SGDRegressor, ElasticNet, RidgeCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import xgboost as xgb
from pylab import *

# %%
# splitting data into train and test datasets
X = input_player_df.copy()
y = dpmu_data_2.copy()
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
y_test.shape
# Out:
# (57975, 36)

# %% [markdown]
# # Ridge with all data and fixed MSE

# %%
#trains the model with the original data
model = Ridge()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[2374.31700699, 2375.4896604 , 2355.96108966, ..., 2353.91283212,
#         2355.02425925, 2350.16513943],
#        [2376.21966173, 2377.40615476, 2359.10391096, ..., 2338.08518205,
#         2339.91273717, 2334.21718076],
#        [2388.69854246, 2389.91753958, 2382.72994711, ..., 2373.99919908,
#         2375.14180459, 2373.10012747],
#        ...,
#        [2390.00706011, 2390.13590957, 2380.4179834 , ..., 2352.32605732,
#         2353.41664041, 2348.63209943],
#        [2391.98975105, 2392.61350289, 2386.5181764 , ..., 2376.18377251,
#         2377.10975398, 2374.94012219],
#        [2394.10111879, 2394.34009649, 2388.85451791, ..., 2382.36637069,
#         2383.08865885, 2381.08085884]])

# %%
#saves the column names to make the y_pred df
names = y_test.columns

# %%
#creates df
df_y_pred = pd.DataFrame(y_pred,columns = names)

# %%
df_y_pred
# Out:
#           MeterA_2     MeterA_1     MeterA_3     MeterA_4       house1  \
# 0      2374.317007  2375.489660  2355.961090  2353.255963  2362.963754
# 1      2376.219662  2377.406155  2359.103911  2356.151059  2363.375255
# 2      2388.698542  2389.917540  2382.729947  2381.444219  2380.241137
# 3      2402.748964  2402.737484  2404.939159  2404.186565  2399.987806
# 4      2384.176247  2384.951639  2372.038059  2369.780409  2375.208597
# ...            ...          ...          ...          ...          ...
# 57970  2378.444530  2379.633784  2363.224065  2360.852944  2368.364225
# 57971  2394.848397  2395.179078  2390.822126  2389.601596  2389.999341
# 57972  2390.007060  2390.135910  2380.417983  2378.260838  2384.314354
# 57973  2391.989751  2392.613503  2386.518176  2385.284171  2386.624684
# 57974  2394.101119  2394.340096  2388.854518  2387.834132  2391.846254
#
#             house4       house7      house13      house10      house22  ...  \
# 0      2372.052137  2371.384152  2349.412033  2355.961090  2355.349741  ...
# 1      2373.938011  2373.227957  2352.507280  2359.103911  2358.263421  ...
# 2      2388.533551  2388.170586  2379.766645  2382.729947  2382.469987  ...
# 3      2403.313779  2403.907636  2402.812876  2404.939159  2404.372723  ...
# 4      2382.691288  2382.379072  2366.889727  2372.038059  2371.405858  ...
# ...            ...          ...          ...          ...          ...  ...
# 57970  2376.792479  2376.173264  2357.625663  2363.224065  2362.592228  ...
# 57971  2394.754463  2394.984706  2387.947764  2390.822126  2390.429376  ...
# 57972  2389.064463  2389.259824  2375.466122  2380.417983  2379.772640  ...
# 57973  2391.708634  2391.617495  2383.769035  2386.518176  2386.318899  ...
# 57974  2394.285826  2394.475257  2386.403102  2388.854518  2388.931574  ...
#
#           MeterC_3     MeterC_4       house3       house6       house9  \
# 0      2355.025164  2351.622513  2356.447601  2364.005149  2362.556663
# 1      2339.914037  2335.913013  2343.716806  2354.480408  2352.564663
# 2      2375.142516  2373.577888  2379.938075  2381.879609  2381.356776
# 3      2359.076163  2357.048676  2372.834417  2378.738249  2378.427235
# 4      2355.645230  2352.793740  2359.241653  2367.046111  2365.735251
# ...            ...          ...          ...          ...          ...
# 57970  2359.208240  2356.551152  2363.149599  2367.320489  2366.065757
# 57971  2368.216453  2366.203699  2374.779989  2380.685767  2380.163482
# 57972  2353.417389  2350.248786  2360.059342  2369.384140  2368.120908
# 57973  2377.110305  2375.620293  2381.924059  2385.063705  2384.658246
# 57974  2383.088876  2381.690825  2387.944654  2389.802582  2389.505211
#
#            house15      house12      house24      house21      house18
# 0      2347.776313  2355.025164  2353.912832  2355.024259  2350.165139
# 1      2331.260108  2339.914037  2338.085182  2339.912737  2334.217181
# 2      2371.400738  2375.142516  2373.999199  2375.141805  2373.100127
# 3      2355.823359  2359.076163  2357.498285  2359.075374  2355.916026
# 4      2349.574588  2355.645230  2354.389305  2355.644296  2351.523140
# ...            ...          ...          ...          ...          ...
# 57970  2353.196731  2359.208240  2357.783580  2359.207257  2355.572384
# 57971  2364.544770  2368.216453  2367.496453  2368.216006  2365.166033
# 57972  2347.549678  2353.417389  2352.326057  2353.416640  2348.632099
# 57973  2374.030698  2377.110305  2376.183773  2377.109754  2374.940122
# 57974  2380.404710  2383.088876  2382.366371  2383.088659  2381.080859
#
# [57975 rows x 36 columns]

# %%
#concatenate both y's so we can scale with respect to both ranges
scaling_all = pd.concat([y_test,df_y_pred], keys=['y_test','y_pred'])

# %%
scaling_all.xs('y_pred')
# Out:
#           MeterA_2     MeterA_1     MeterA_3     MeterA_4       house1  \
# 0      2374.317007  2375.489660  2355.961090  2353.255963  2362.963754
# 1      2376.219662  2377.406155  2359.103911  2356.151059  2363.375255
# 2      2388.698542  2389.917540  2382.729947  2381.444219  2380.241137
# 3      2402.748964  2402.737484  2404.939159  2404.186565  2399.987806
# 4      2384.176247  2384.951639  2372.038059  2369.780409  2375.208597
# ...            ...          ...          ...          ...          ...
# 57970  2378.444530  2379.633784  2363.224065  2360.852944  2368.364225
# 57971  2394.848397  2395.179078  2390.822126  2389.601596  2389.999341
# 57972  2390.007060  2390.135910  2380.417983  2378.260838  2384.314354
# 57973  2391.989751  2392.613503  2386.518176  2385.284171  2386.624684
# 57974  2394.101119  2394.340096  2388.854518  2387.834132  2391.846254
#
#             house4       house7      house13      house10      house22  ...  \
# 0      2372.052137  2371.384152  2349.412033  2355.961090  2355.349741  ...
# 1      2373.938011  2373.227957  2352.507280  2359.103911  2358.263421  ...
# 2      2388.533551  2388.170586  2379.766645  2382.729947  2382.469987  ...
# 3      2403.313779  2403.907636  2402.812876  2404.939159  2404.372723  ...
# 4      2382.691288  2382.379072  2366.889727  2372.038059  2371.405858  ...
# ...            ...          ...          ...          ...          ...  ...
# 57970  2376.792479  2376.173264  2357.625663  2363.224065  2362.592228  ...
# 57971  2394.754463  2394.984706  2387.947764  2390.822126  2390.429376  ...
# 57972  2389.064463  2389.259824  2375.466122  2380.417983  2379.772640  ...
# 57973  2391.708634  2391.617495  2383.769035  2386.518176  2386.318899  ...
# 57974  2394.285826  2394.475257  2386.403102  2388.854518  2388.931574  ...
#
#           MeterC_3     MeterC_4       house3       house6       house9  \
# 0      2355.025164  2351.622513  2356.447601  2364.005149  2362.556663
# 1      2339.914037  2335.913013  2343.716806  2354.480408  2352.564663
# 2      2375.142516  2373.577888  2379.938075  2381.879609  2381.356776
# 3      2359.076163  2357.048676  2372.834417  2378.738249  2378.427235
# 4      2355.645230  2352.793740  2359.241653  2367.046111  2365.735251
# ...            ...          ...          ...          ...          ...
# 57970  2359.208240  2356.551152  2363.149599  2367.320489  2366.065757
# 57971  2368.216453  2366.203699  2374.779989  2380.685767  2380.163482
# 57972  2353.417389  2350.248786  2360.059342  2369.384140  2368.120908
# 57973  2377.110305  2375.620293  2381.924059  2385.063705  2384.658246
# 57974  2383.088876  2381.690825  2387.944654  2389.802582  2389.505211
#
#            house15      house12      house24      house21      house18
# 0      2347.776313  2355.025164  2353.912832  2355.024259  2350.165139
# 1      2331.260108  2339.914037  2338.085182  2339.912737  2334.217181
# 2      2371.400738  2375.142516  2373.999199  2375.141805  2373.100127
# 3      2355.823359  2359.076163  2357.498285  2359.075374  2355.916026
# 4      2349.574588  2355.645230  2354.389305  2355.644296  2351.523140
# ...            ...          ...          ...          ...          ...
# 57970  2353.196731  2359.208240  2357.783580  2359.207257  2355.572384
# 57971  2364.544770  2368.216453  2367.496453  2368.216006  2365.166033
# 57972  2347.549678  2353.417389  2352.326057  2353.416640  2348.632099
# 57973  2374.030698  2377.110305  2376.183773  2377.109754  2374.940122
# 57974  2380.404710  2383.088876  2382.366371  2383.088659  2381.080859
#
# [57975 rows x 36 columns]

# %%
#scaling the df
scaler = StandardScaler()
scaler.fit(scaling_all)
#scaler.transform(scaling_df)
# Out:
# StandardScaler()

# %%
#storing scaled values into a df
scaledDF = pd.DataFrame(scaler.transform(scaling_all),columns = names)

# %%
#splitting df back into the y_pred and y_test
scaled_y_pred = scaledDF[:57975]
scaled_y_test = scaledDF[57975:]

# %%
#finding L2 norm of the y_test_scaled vectors
L2_ratios = []
for index, row in scaled_y_test.iterrows():
    L2_ratios.append(LA.norm(row))

# %%
L2_ratios[0]
# Out:
# 5.376214345486007

# %%
#dividing all y_pred by the L2 ratios:
ratio_index = 0
scaled_ratio_y_pred = []
for index, row in scaled_y_pred.iterrows():
    scaled_ratio_y_pred.append(row/L2_ratios[ratio_index])
    ratio_index += 1

scaled_ratio_y_pred

# %%
print("MSE: ", (mean_squared_error(scaled_y_test, scaled_ratio_y_pred)))
# Out:
# MSE:  0.5232381551944892

# %% [markdown]
# ## Ordinary Least Squares

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

scaler = StandardScaler()
scaler.fit(y_pred)
scaler.transform(y_pred)

scaler_test = StandardScaler()
scaler_test.fit(y_test)
scaler_test.transform(y_test)

print("MSE: ", (mean_squared_error(scaler_test.transform(y_test), scaler_pred.transform(y_pred))))
# Out:
# MSE:  1.0158591891989472

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("MSE: ", (mean_squared_error(y_test, y_pred)))
# Out:
# MSE:  0.012124357406555458

# %%
y_test
# Out:
# array([[0.43024622, 0.42986057, 0.44234119, ..., 0.45515354, 0.45854115,
#         0.46895496],
#        [0.69990555, 0.71149465, 0.73133722, ..., 0.55384852, 0.54961779,
#         0.55760762],
#        [0.82572067, 0.81447713, 0.84282362, ..., 0.45870779, 0.46482167,
#         0.46502154],
#        ...,
#        [0.5397708 , 0.53871576, 0.55593516, ..., 0.52208204, 0.51849853,
#         0.52254762],
#        [0.67406778, 0.65523436, 0.64788456, ..., 0.73079766, 0.7247211 ,
#         0.7325962 ],
#        [0.39451788, 0.38331792, 0.36218836, ..., 0.58653476, 0.58105477,
#         0.59045469]])

# %%
y_pred
# Out:
# array([[0.46029834, 0.45509918, 0.44810196, ..., 0.49324218, 0.48917813,
#         0.49612703],
#        [0.59275047, 0.59725945, 0.61237036, ..., 0.62708905, 0.6269492 ,
#         0.63609951],
#        [0.76315693, 0.75296435, 0.76081399, ..., 0.6191779 , 0.6231838 ,
#         0.63001511],
#        ...,
#        [0.59252091, 0.59247304, 0.58884076, ..., 0.54180885, 0.54037541,
#         0.55271366],
#        [0.64564669, 0.63943248, 0.64425246, ..., 0.72264428, 0.72011022,
#         0.7210659 ],
#        [0.57946729, 0.57699505, 0.57853069, ..., 0.51783075, 0.5222306 ,
#         0.53818593]])

# %%
# normalise data
# use rmse and scale it to the original signal -> what is the magnitude of the signal we are trying to predict
# every sample is 24x1 -> what is the average norm of that vector? -> how to evaluate error of model
# mse grows linearly with inputs

# %%
y_pred.shape
# Out:
# (14732, 36)

# %% [markdown]
# ## Lasso Model

# %%
model = Lasso()

model.fit(X_train, y_train)
        
y_pred = model.predict(X_test)
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.0171241204202973

# %% [markdown]
# ## Ridge Model

# %%
model = Ridge()
model.fit(X_train, y_train)
        
y_pred = model.predict(X_test)
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.012124322218466712

# %%
model = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1]).fit(X_train, y_train)
y_pred = model.predict(X_test)
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.010152678682675316

# %% [markdown]
# ## Elastic Net with Cross Validation and Hyperparameter Tuning

# %%
model = ElasticNet()

# define model evaluation method
cv = RepeatedKFold(n_splits=3, n_repeats=3, random_state=1)
# define grid
grid = dict()
grid['alpha'] = [1e-2, 1e-1, 1]
grid['l1_ratio'] = arange(0, 1, 0.1)
# define search
search = GridSearchCV(model, grid, scoring='neg_mean_squared_error', cv=cv, n_jobs=-1)
# perform the search
results = search.fit(X_train, y_train)
# summarize
print('MSE: %.3f' % results.best_score_)
print('Config: %s' % results.best_params_)

# %%
model = ElasticNet()

# %%
model = ElasticNet(alpha=100, l1_ratio=0.0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("MSE: ", mean_squared_error(y_test, y_pred))
# Out:
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 251.82952949721698, tolerance: 0.05041201135548906
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 246.45765555344084, tolerance: 0.04933683279040945
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 266.86680688287987, tolerance: 0.05342448643325658
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 255.57731710229797, tolerance: 0.051164853920694586
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 348.5959557285708, tolerance: 0.06979173770822632
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 251.0560505360056, tolerance: 0.0502599162083866
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 251.60659589026267, tolerance: 0.05037057339905545
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 248.30063259023427, tolerance: 0.04970889855968858
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 270.4935736594981, tolerance: 0.05415140883875635
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 266.8758603374802, tolerance: 0.05342630008065377
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 254.45702890868998, tolerance: 0.05094110248401249
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 182.76993012905896, tolerance: 0.03655885062325224
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 187.17987960622705, tolerance: 0.03744111692567943
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 185.23384587116507, tolerance: 0.037052336741708394
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 192.70929807944606, tolerance: 0.03854748829687261
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 224.35681865664824, tolerance: 0.04488455760615869
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 195.82961801026588, tolerance: 0.03917118880269752
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 196.05005779251647, tolerance: 0.03921527078452287
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 197.3505576454725, tolerance: 0.039475200544262866
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 184.39832506809392, tolerance: 0.03688512258285307
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 185.23635285998307, tolerance: 0.037052838089658535
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202.16938033884495, tolerance: 0.04044029109111813
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 338.80152701641066, tolerance: 0.06785352736892307
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 341.6831657463027, tolerance: 0.06842842822025764
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 287.42338911586666, tolerance: 0.05755048742892406
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 281.80942741955545, tolerance: 0.056426093934310875
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320.4964823607384, tolerance: 0.06418996881972729
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 340.9315885022142, tolerance: 0.0682855439640901
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 333.39574314100304, tolerance: 0.0667765930407424
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 288.65864528996906, tolerance: 0.05779873249115196
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 292.56381116999387, tolerance: 0.05857850176737018
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 287.43252122054, tolerance: 0.057552316238576304
#   model = cd_fast.enet_coordinate_descent(
# MSE:  0.017094343589100527
# C:\Users\aniss\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 275.8723096034738, tolerance: 0.0552368007903797
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# # Neural Network

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import RepeatedKFold
from keras.models import Sequential
from keras.layers import Dense

# %%
# get the dataset
def get_dataset():
    X, y = input_player_df.copy().to_numpy(), dpmu_data.copy().to_numpy()
    return X, y

# %%
# get the model
def get_model(n_inputs, n_outputs):
    model = Sequential()
    model.add(Dense(20, input_dim=n_inputs, kernel_initializer='he_uniform', activation='relu'))
    model.add(Dense(n_outputs))
    model.compile(loss='mse', optimizer='adam')
    return model

# %%
# evaluate a model using repeated k-fold cross-validation
def evaluate_model(X, y):
    results = list()
    n_inputs, n_outputs = X.shape[1], y.shape[1]
    # define evaluation procedure
    cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
    # enumerate folds
    for train_ix, test_ix in cv.split(X):
        # prepare data
        X_train, X_test = X[train_ix], X[test_ix]
        y_train, y_test = y[train_ix], y[test_ix]
        # define model
        model = get_model(n_inputs, n_outputs)
        # fit model
        model.fit(X_train, y_train, verbose=0, epochs=100)
        # evaluate model on test set
        mse = model.evaluate(X_test, y_test, verbose=0)
        # store result
        print(mse)
        results.append(mse)
        return results

# %%
# load dataset
X, y = get_dataset()
# evaluate model
results = evaluate_model(X, y)
# summarize performance
print('MSE: %.3f (%.3f)' % (mean(results), std(results)))
